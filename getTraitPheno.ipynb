# %%
import pandas as pd
data = pd.read_csv('full_phenotype_may', sep=" ")
# data.columns = ["a", "b", "c", "etc."]

# %matplotlib inline

# %%
data
# Out:
#           f.eid  f.4079.0.0  f.4079.0.1  f.4079.1.0  f.4079.1.1  f.4079.2.0  \
# 0       1596781        95.0        96.0         NaN         NaN         NaN
# 1       2206298        67.0        72.0         NaN         NaN         NaN
# 2       4943355        92.0        87.0         NaN         NaN         NaN
# 3       2196527       109.0       109.0         NaN         NaN         NaN
# 4       3414881        80.0        89.0         NaN         NaN         NaN
# 5       3860153       105.0        98.0         NaN         NaN         NaN
# 6       3395450         NaN        72.0         NaN         NaN         NaN
# 7       5835422        88.0        84.0         NaN         NaN         NaN
# 8       1696092        69.0        71.0         NaN         NaN         NaN
# 9       3841801        77.0        73.0         NaN         NaN         NaN
# 10      5027183        80.0        84.0         NaN         NaN         NaN
# ...

# %%
print(data.columns)
# Out:
# Index(['f.eid', 'f.4079.0.0', 'f.4079.0.1', 'f.4079.1.0', 'f.4079.1.1',
#        'f.4079.2.0', 'f.4079.2.1', 'f.94.0.0', 'f.94.0.1', 'f.94.1.0',
#        'f.94.1.1', 'f.94.2.0', 'f.94.2.1', 'f.95.0.0', 'f.21001.0.0',
#        'f.21001.1.0', 'f.21001.2.0', 'f.21003.0.0', 'f.21003.1.0',
#        'f.21003.2.0'],
#       dtype='object')

# %%
from pysnptools.snpreader import Bed
snps = Bed('/Users/ioneliabuzatu/PycharmProjects/biobank/nogitdata/ukb_cal_chr1_v2',count_A1=False)


pheno_patient_id = []
for patient in snps.iid[:100]:
    id = patient[0].decode('utf8').strip()  # from 2 to -1
    id = int(id)
    pheno_patient_id.append(id)

# %%
# data.set_index("f.eid", inplace=True)
data
# Out:
#          f.4079.0.0  f.4079.0.1  f.4079.1.0  f.4079.1.1  f.4079.2.0  \
# f.eid
# 1596781        95.0        96.0         NaN         NaN         NaN
# 2206298        67.0        72.0         NaN         NaN         NaN
# 4943355        92.0        87.0         NaN         NaN         NaN
# 2196527       109.0       109.0         NaN         NaN         NaN
# 3414881        80.0        89.0         NaN         NaN         NaN
# 3860153       105.0        98.0         NaN         NaN         NaN
# 3395450         NaN        72.0         NaN         NaN         NaN
# 5835422        88.0        84.0         NaN         NaN         NaN
# 1696092        69.0        71.0         NaN         NaN         NaN
# 3841801        77.0        73.0         NaN         NaN         NaN
# 5027183        80.0        84.0         NaN         NaN         NaN
# 5796421        86.0        87.0         NaN         NaN         NaN
# 5610809        71.0        71.0         NaN         NaN         NaN
# ...

# %%
pheno_patient_id[:5]
# Out:
# [1505458, 1738124, 5547326, 4351246, 3590647]

# %%
data = data.loc[pheno_patient_id]

# %%
data = data.loc[:, ["f.4079.0.0", "f.21003.0.0"]]

# %%
data.columns = ["BlodP", "BodyS"]

# %%
data
# Out:
#          BlodP  BodyS
# f.eid
# 1505458   78.0     41
# 1738124   93.0     46
# 5547326   90.0     52
# 4351246   81.0     65
# 3590647  106.0     56
# 3714710   96.0     50
# 1079689   76.0     41
# 2753720   89.0     51
# 5624950   72.0     53
# 5016326   94.0     50
# 5313241   89.0     55
# 2955001   91.0     58
# 5611832   91.0     55
# 5874651   84.0     47
# 3732041   76.0     45
# 5085585   95.0     48
# 4795688   74.0     41
# 1706523   75.0     63
# 3767671   99.0     64
# 1121821   85.0     53
# 3585992   92.0     54
# 2561431   86.0     54
# 2728319  102.0     60
# 1244152   83.0     61
# 1496142   82.0     50
# 1304987   67.0     53
# 1936014   81.0     58
# 1887277   98.0     42
# 2719300   96.0     43
# 4783550   98.0     51
# ...        ...    ...
# 2370662   92.0     63
# 2129400   68.0     67
# 2233432   86.0     65
# 5808565   88.0     58
# 1389426   61.0     52
# 4306827   94.0     59
# 3132377   81.0     64
# 5876766   84.0     43
# 1941243   75.0     60
# ...

# %%
data.to_csv("pheno100.csv", sep='\t')
